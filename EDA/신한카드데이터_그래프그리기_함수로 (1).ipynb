# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame(pd.read_excel('C:/Users/ASIA_07/Downloads/신한카드데이터.xlsx'))

# %%
data[data['이용일자'] > 20200101]
# Out:
#           이용일자      업종대분류  카드결제건수(천건)
# 3185  20200102      가전/가구         250
# 3186  20200102   가정생활/서비스         541
# 3187  20200102      교육/학원         537
# 3188  20200102         미용         523
# 3189  20200102  스포츠/문화/레저        1581
# ...        ...        ...         ...
# 5533  20200630      음/식료품        1549
# 5534  20200630         의료        2887
# 5535  20200630        자동차         418
# 5536  20200630         주유        2008
# 5537  20200630      패션/잡화         360
#
# [2353 rows x 3 columns]

# %%
# 매일마다 있음
data['이용일자'].iloc[40]
# Out:
# 20190104

# %%
# 3월초 - 대구 
# 8월 - 전국 확산

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
food = []
for i in range(len(data)) :
    if data['업종대분류'].iloc[i] == '음/식료품' :
        food.append(i)

# %%
data_food1 = data[8::13]
data_food2 = data[6::13]

# %%
data_food1
# Out:
#           이용일자  업종대분류  카드결제건수(천건)
# 8     20190101  음/식료품        1192
# 21    20190102  음/식료품        1241
# 34    20190103  음/식료품        1285
# 47    20190104  음/식료품        1376
# 60    20190105  음/식료품        1499
# ...        ...    ...         ...
# 5481  20200626  음/식료품        1868
# 5494  20200627  음/식료품        2069
# 5507  20200628  음/식료품        1631
# 5520  20200629  음/식료품        1551
# 5533  20200630  음/식료품        1549
#
# [426 rows x 3 columns]

# %%
data_food2
# Out:
#           이용일자  업종대분류  카드결제건수(천건)
# 6     20190101  요식/유흥        9264
# 19    20190102  요식/유흥        9481
# 32    20190103  요식/유흥       10082
# 45    20190104  요식/유흥       10948
# 58    20190105  요식/유흥       11327
# ...        ...    ...         ...
# 5479  20200626  요식/유흥       12006
# 5492  20200627  요식/유흥       12519
# 5505  20200628  요식/유흥       10860
# 5518  20200629  요식/유흥        9752
# 5531  20200630  요식/유흥       10358
#
# [426 rows x 3 columns]

# %%
data_food1.iloc[250:273]
# Out:
#           이용일자  업종대분류  카드결제건수(천건)
# 3258  20200107  음/식료품        1214
# 3271  20200108  음/식료품        1443
# 3284  20200109  음/식료품        1441
# 3297  20200110  음/식료품        1552
# 3310  20200111  음/식료품        1696
# 3323  20200112  음/식료품        1344
# 3336  20200113  음/식료품        1454
# 3349  20200114  음/식료품        1463
# 3362  20200115  음/식료품        1478
# 3375  20200116  음/식료품        1509
# 3388  20200117  음/식료품        1648
# 3401  20200118  음/식료품        1819
# 3414  20200119  음/식료품        1419
# 3427  20200120  음/식료품        1675
# 3440  20200121  음/식료품        1782
# 3453  20200122  음/식료품        2055
# 3466  20200123  음/식료품        2994
# 3479  20200124  음/식료품        3011
# 3492  20200125  음/식료품         920
# 3505  20200126  음/식료품        1024
# 3518  20200127  음/식료품         813
# 3531  20200128  음/식료품        1081
# 3544  20200129  음/식료품        1184

# %%
import matplotlib.pyplot as plt

# %%
xtic = np.arange(0,len(data_food1),step=30) 
days = data_food1['이용일자'].values[:]
xdays = [days[i] for i in xtic]
xtic = xtic*13

# %%
#음식료품
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

s1 = data_food1["카드결제건수(천건)"]
ax1 = s1.plot()
plt.axvline(x=3440, label="중국 첫 코로나", color ='red')
plt.title("shinhancard_food_drink")
plt.xticks(xtic,xdays, rotation = 90)
plt.show()

# %%
# 요식/유흥
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

s2 = data_food2["카드결제건수(천건)"]
ax2 = s2.plot()
plt.axvline(x=3440, label="중국 첫 코로나", color ='red')
plt.title("shinhancard_restaurant")
plt.xticks(xtic,xdays, rotation = 90)
plt.show()

# %%
data.head(14)
# Out:
#         이용일자      업종대분류  카드결제건수(천건)
# 0   20190101      가전/가구         149
# 1   20190101   가정생활/서비스         189
# 2   20190101      교육/학원         142
# 3   20190101         미용         464
# 4   20190101  스포츠/문화/레저        1752
# 5   20190101      여행/교통         260
# 6   20190101      요식/유흥        9264
# 7   20190101         유통       11307
# 8   20190101      음/식료품        1192
# 9   20190101         의료         432
# 10  20190101        자동차         186
# 11  20190101         주유        1782
# 12  20190101      패션/잡화         415
# 13  20190102      가전/가구         239

# %%
""" 0  - 가전/가구 . 1 - 가정생활/서비스 . 2- 교육/학원 . 3 - 미용
    4 - 스포츠/문화/레저 .  5- 여행/교통  6. 요식/유흥 7. 유통
    8 - 음/식료품 . 9 - 의료 . 10 -자동차. 11 - 주유 . 12- 패션/잡화 """
    
    
def make_graph(num) :
    data_make = data[num::13]
    xtic = np.arange(0,len(data_make),step=30) 
    days = data_make['이용일자'].values[:]
    xdays = [days[i] for i in xtic]
    xtic = xtic*13
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    s1 = data_make["카드결제건수(천건)"]
    ax1 = s1.plot()
    plt.axvline(x=3440, label="중국 첫 코로나", color ='red')     # 빨간선은 코로나 시작 시점
    plt.title("the graph")
    plt.xticks(xtic,xdays, rotation = 90)
    plt.show()

# %%
# 가전 /가구 
make_graph(0)

# %%
# 1 - 가정생활/서비스
make_graph(1)

# %%
# 2- 교육/학원
make_graph(2)

# %%
#  3 - 미용
make_graph(3)

# %%
# 4 - 스포츠/문화/레저 .
make_graph(4)

# %%
#  5- 여행/교통 
make_graph(5)

# %%
# 6. 요식/유흥
make_graph(6)

# %%
# 7. 유통
make_graph(7)

# %%
# 8 - 음/식료품 .
make_graph(8)

# %%
# 9 - 의료 .
make_graph(9)

# %%
#  10 -자동차.
make_graph(10)

# %%
#  11 - 주유 
make_graph(11)

# %%
#  12- 패션/잡화
make_graph(12)

# %%
make_graph(13)

# %%
make_graph(14)

# %%
make_graph(15)
