# %%
from selenium import webdriver as wd 
from bs4 import BeautifulSoup 
import time

import requests 
from bs4 import BeautifulSoup

# %%
url = 'https://www.youtube.com/results?search_query=%EC%98%A4%EB%9A%9C%EA%B8%B0+%EB%AF%B8%EC%97%AD%EC%B4%88+%EB%B9%84%EB%B9%94%EB%A9%B4' 
req = requests.get(url) 
soup = BeautifulSoup(req.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
def youcrawl(url):    

    driver = wd.Chrome(executable_path="chromedriver.exe")
    driver.get(url)
    last_page_height = driver.execute_script("return document.documentElement.scrollHeight") 

    while True:
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(3.0)
        new_page_height = driver.execute_script("return document.documentElement.scrollHeight")

        if new_page_height == last_page_height:
            break
        last_page_height = new_page_height

    html_source = driver.page_source

    driver.close()

    soup = BeautifulSoup(html_source, 'lxml')
    youtube_comments = soup.select('yt-formatted-string#content-text')

    str_youtube_comments = []

    for i in range(len(youtube_comments)):
        str_tmp = str(youtube_comments[i].text)
       # str_tmp = str_tmp.replace('\n', '')
       # str_tmp = str_tmp.replace('\t', '')
       # str_tmp = str_tmp.replace(' ', '')

        str_youtube_comments.append(str_tmp)
    return str_youtube_comments

# %%
ulist = ['https://www.youtube.com/watch?v=guKyqtWi17s',
 'https://www.youtube.com/watch?v=cSQdBVnVLn8',
 'https://www.youtube.com/watch?v=w1BD7PWMobs',
 'https://www.youtube.com/watch?v=qDSx25Bl78M',
 'https://www.youtube.com/watch?v=dD1aMjK3yWY',
 'https://www.youtube.com/watch?v=2Fs2w71E9ks',
 'https://www.youtube.com/watch?v=DiBupjharR0',
 'https://www.youtube.com/watch?v=pLUeREUbbB4',
 'https://www.youtube.com/watch?v=24n1HpzDJtY',
 'https://www.youtube.com/watch?v=E_jvOIn3rjc',
 'https://www.youtube.com/watch?v=5YHOhrz8ETY',
 'https://www.youtube.com/watch?v=a7YvClSbOWY',
 'https://www.youtube.com/watch?v=CLCIZkqixyw',
 'https://www.youtube.com/watch?v=Zx_aXOOKaU8',
 'https://www.youtube.com/watch?v=OxWxEYx5ns0',
 'https://www.youtube.com/watch?v=5uVPOr51Ip4',
 'https://www.youtube.com/watch?v=AdCXw3Wm6lU',
 'https://www.youtube.com/watch?v=zEDb4WsTwkg',
 'https://www.youtube.com/watch?v=NRPN9NNmq8o',
 'https://www.youtube.com/watch?v=P1jt23WmT5U',
 'https://www.youtube.com/watch?v=av3sta6L5-Q',
 'https://www.youtube.com/watch?v=6fg6LnIwpFk',
 'https://www.youtube.com/watch?v=mWpP02Suzxk',
 'https://www.youtube.com/watch?v=1nE6Z3cOQpw',
 'https://www.youtube.com/watch?v=W90CcRwrCg0',
 'https://www.youtube.com/watch?v=lHmscvFI3bA',
 'https://www.youtube.com/watch?v=ODnMraaXHSU',
 'https://www.youtube.com/watch?v=GvAHDg1iIIA',
 'https://www.youtube.com/watch?v=KntJbnaSWEQ',
 'https://www.youtube.com/watch?v=hzMGpTg9nx4',
 'https://www.youtube.com/watch?v=RQZcIo4eHYY',
 'https://www.youtube.com/watch?v=YJ-cfse3JoA',
 'https://www.youtube.com/watch?v=6EfzT-MD2MU',
 'https://www.youtube.com/watch?v=KHhzb6MqZ3Q',
 'https://www.youtube.com/watch?v=_Z68q3X6eoE',
 'https://www.youtube.com/watch?v=-mKMM4-O8bE',
 'https://www.youtube.com/watch?v=hrvvTqiiVSM',
 'https://www.youtube.com/watch?v=nO2GAeWmiqg',
 'https://www.youtube.com/watch?v=C_DNQnkKFno',
 'https://www.youtube.com/watch?v=c5nlnOBpNz4',
 'https://www.youtube.com/watch?v=RQZeSE4EPUE',
 'https://www.youtube.com/watch?v=PFLl-yu6eJI',
 'https://www.youtube.com/watch?v=OnHHB1yO_kw',
 'https://www.youtube.com/watch?v=bvEc7Sc8wbU',
'https://www.youtube.com/watch?v=67_t0IRDPkM',
'https://www.youtube.com/watch?v=wyT3pp6dLyI']

# %%
ulist2 = []
for u in ulist:
    ulist2.append(youcrawl(u))

# %%
ulist2
# Out:
# [['이 영상 왜인지 모르게 마약영상임... 지금만 구라안치고 100번 넘게 본 듯 ... 컨텐츠 아닌 평소 시카언니 넘 기여웡 ㅠ,ㅠ',
#   '아저씨가 장사를 잘하네',
#   '아저씨가 그러는데 마트가  유행이래 . 그래서 마트를 삿고',
#   '귀가 너무 얇은거 아니에요? ㅋㅋㅋ 아저씨가 수박바에서 레몬맛 난다고해도 믿으실듯 ㅋㅋㅋ',
#   '5:58ㅋㅋㅋㅋ "으음..옴뫄 어어얽!!! ........오오~~"ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ귀여웤ㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '아저씨가 많이먹는게 유행이래 ㅋㅋㅋ',
#   '가장 재밌었던 부분의 시간을 남겨주세요^^ ( 바로클릭해볼께요)',
#   '솔직히 말해봐요 그냥 언니가 먹고싶은거 사온거죠?ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ저정도면 아저씨가 언니 호갱으로 본거아니에여..?',
#   '6:01 정지해서보면 개웃긴ㅋㅋㅋ',
#   '19:29\xa0 너무 진지햌ㅋㅋㅋㅋㅋㅋ',
#   '6:00부터 너무 웃곀ㅋㅋㅋㅋㅋㅋㅋㅋㅋ\n엄마 으악 하다가 진지해지는뎈ㅋㅋㅋㅋㅋㅋ',
#   '코찡이 전문용어가 아닌데 모든 사람들이 알아듣는닼ㅋㅋㅋㅋㅋㅋㅋ',
#   '※와사비마요 주의점※\n\n와사비는 자기 기호량 만큼 넣으셔야 맛납니당',
#   '*아저씨가 그러는데*이부분 진짜 좋아요ㅋㅋㅋㅋㅋㅋㅋ',
#   '언니 댓글 보시는지는 모르겟지만 창원 북면 골프장 살인사건 얘기 해주심 안될까요? 창원 북면 골프장 주변에 사는데 살인사건이 너무 많이 생겨요 낙동강? 거기에서 타살인지 자살인지 모르는 여자 시체가 발견되고 여자 소리지르는 소리도 많이 들리고요 정말 골프장 살인사건이 너무 화나는 내용이라 해주시면 안될가요?',
#   '이쯤되면 아저씨 편의점 재고정리 의심된다...',
#   '화장법 바꾸셨나여!??? 왤케 예뻐졌어요  보는데 갑자기 너무 예뻐지셔서 놀랐어요 제시카언니 짱예(쁨)❤️❤️💗',
#   '아직 10댄데 아이스크림 깨물어 못먹어욬ㅋㅋㅋ 이가 시려섴ㅋㅋ',
# ...

# %%
#리스트 안의 리스트를 풀어서 중첩되지 않은 하나의 리스트로 만들 때 간단한 방법:
ulist2=sum(ulist2, [])
ulist2
# Out:
# ['이 영상 왜인지 모르게 마약영상임... 지금만 구라안치고 100번 넘게 본 듯 ... 컨텐츠 아닌 평소 시카언니 넘 기여웡 ㅠ,ㅠ',
#  '아저씨가 장사를 잘하네',
#  '아저씨가 그러는데 마트가  유행이래 . 그래서 마트를 삿고',
#  '귀가 너무 얇은거 아니에요? ㅋㅋㅋ 아저씨가 수박바에서 레몬맛 난다고해도 믿으실듯 ㅋㅋㅋ',
#  '5:58ㅋㅋㅋㅋ "으음..옴뫄 어어얽!!! ........오오~~"ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ귀여웤ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아저씨가 많이먹는게 유행이래 ㅋㅋㅋ',
#  '가장 재밌었던 부분의 시간을 남겨주세요^^ ( 바로클릭해볼께요)',
#  '솔직히 말해봐요 그냥 언니가 먹고싶은거 사온거죠?ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ저정도면 아저씨가 언니 호갱으로 본거아니에여..?',
#  '6:01 정지해서보면 개웃긴ㅋㅋㅋ',
#  '19:29\xa0 너무 진지햌ㅋㅋㅋㅋㅋㅋ',
#  '6:00부터 너무 웃곀ㅋㅋㅋㅋㅋㅋㅋㅋㅋ\n엄마 으악 하다가 진지해지는뎈ㅋㅋㅋㅋㅋㅋ',
#  '코찡이 전문용어가 아닌데 모든 사람들이 알아듣는닼ㅋㅋㅋㅋㅋㅋㅋ',
#  '※와사비마요 주의점※\n\n와사비는 자기 기호량 만큼 넣으셔야 맛납니당',
#  '*아저씨가 그러는데*이부분 진짜 좋아요ㅋㅋㅋㅋㅋㅋㅋ',
#  '언니 댓글 보시는지는 모르겟지만 창원 북면 골프장 살인사건 얘기 해주심 안될까요? 창원 북면 골프장 주변에 사는데 살인사건이 너무 많이 생겨요 낙동강? 거기에서 타살인지 자살인지 모르는 여자 시체가 발견되고 여자 소리지르는 소리도 많이 들리고요 정말 골프장 살인사건이 너무 화나는 내용이라 해주시면 안될가요?',
#  '이쯤되면 아저씨 편의점 재고정리 의심된다...',
#  '화장법 바꾸셨나여!??? 왤케 예뻐졌어요  보는데 갑자기 너무 예뻐지셔서 놀랐어요 제시카언니 짱예(쁨)❤️❤️💗',
#  '아직 10댄데 아이스크림 깨물어 못먹어욬ㅋㅋㅋ 이가 시려섴ㅋㅋ',
# ...

# %%
import pandas as pd

cream_data = {"Comment":ulist2}

cream_pd = pd.DataFrame(cream_data)

# %%
cream_pd
# Out:
#                                                  Comment
# 0      이 영상 왜인지 모르게 마약영상임... 지금만 구라안치고 100번 넘게 본 듯 .....
# 1                                           아저씨가 장사를 잘하네
# 2                       아저씨가 그러는데 마트가  유행이래 . 그래서 마트를 삿고
# 3      귀가 너무 얇은거 아니에요? ㅋㅋㅋ 아저씨가 수박바에서 레몬맛 난다고해도 믿으실듯 ㅋㅋㅋ
# 4      5:58ㅋㅋㅋㅋ "으음..옴뫄 어어얽!!! ........오오~~"ㅋㅋㅋㅋㅋㅋㅋㅋㅋ...
# ...                                                  ...
# 13580                                    이거 진짜 개노맛 왜만든거지
# 13581          모자 간지나시네~~~~\n앞아로는 이런거 말고 맛있는거 드셔주세욬ㅋㅋㅋㅋㅋ
# 13582                 컵라면 하나에 40분 실화냐...\n전 빨리 먹고 후기 하는줄
# 13583           1:15 입안에 내용물이 안보이게 손으로 가려서해주셨으면 좋겠어용 ㅎㅎ❤
# 13584  뭔가  철없고  불쌍해보이고  백수같이 생겼다ㅋㅋㅋㅋㅋ 그리고  덤으로  못생김ㅋㅋㅋㅋㅋ
#
# [13585 rows x 1 columns]

# %%
# 데이터프레임을 csv파일 형태로 내보내기 

cream_pd.to_csv('cream.csv', index = False)

# %%
# !pip install openpyxl
# Out:
# ...
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8920 sha256=6090ab263aef54d97661b3aa7a721c1e92b1b741a999608f5073520f514724a6
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\ef\92\e0\956c00decf3091294b8800d9104f6169a1adacfaafd122ed42
# Successfully built et-xmlfile
# ...

# %%
cream_pd.to_excel('와사마요.xlsx', index = False)
